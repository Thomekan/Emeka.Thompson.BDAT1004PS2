# %% [markdown]
# ## Question 1

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2
b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# The value displayed after the last expression is 6. In the first three statements, calling b(), no value was returned. This is because the function b() is instructed to return a new function, b(), that assigns a new value to a, overwriting the global a.
# Each time the function b() is called, 2 is added to the new global a.
# Therefore, the final expression:
# = a + b() + b() + b()
# = 0 + 2 + 2 + 2
# = 6

# %% [markdown]
# ## Question 2

# %%
def fileLength(file_name):
    
    
    try:
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))
    
    except FileNotFoundError:
        print("The file", str(file_name), "cannot be found")

# %%
fileLength('Filelength.txt')
# Out:
# 123

# %%
fileLength('idterm.py')
# Out:
# The file ' idterm.py ' cannot be found

# %% [markdown]
# ## Question 3

# %%
class Marsupial ():
    def __init__(self):
        self.list = []
    
    def put_in_pouch(self, item):
        self.list.append(item)
    
    def pouch_contents(self):
        return self.list

# %%
m = Marsupial() 
m.put_in_pouch('doll') 
m.put_in_pouch('firetruck') 
m.put_in_pouch('kitten') 
m.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
class Kangaroo(Marsupial):
    def __init__(self,x,y):
        Marsupial.__init__(self)
        self.x = x
        self.y = y

    def jump(self,dx,dy):
        self.x = dx
        self.y = dy
    def __str__(self):
        return 'I am a kangaroo located at coordinates {}, {}'.format(self.x, self.y)

# %%
k = Kangaroo(0,0) 
print(k)
# Out:
# I am a kangaroo located at coordinates 0, 0

# %%
k.put_in_pouch('doll') 
k.put_in_pouch('firetruck') 
k.put_in_pouch('kitten') 
k.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
k.jump(1,0) 
k.jump(1,0) 
k.jump(1,0)
print(k)
# Out:
# I am a kangaroo located at coordinates 1, 0

# %% [markdown]
# ## Question 4

# %%
def collatz(x):
    
    print (int(x))
    sequence = 1
    if x <= 1:    
        return sequence
        
    if x%2 == 0:
        sequence =(collatz(x/2)+1)
    elif x%2 ==1:
        sequence = (collatz(3*x+1)+1)
    return sequence

# %%
collatz(1)
# Out:
# 1
# 1

# %%
collatz(11)
# Out:
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# 15

# %% [markdown]
# ## Question 5

# %%
def binary(n):
    
    if n <= 0:    
        return 0
    
    else:
        binary(n//2)
        print (n%2, end=' ')

# %%
binary(0)
# Out:
# 0

# %%
binary(1)
# Out:
# 1

# %%
binary(3)
# Out:
# 1 1

# %%
binary(9)
# Out:
# 1 0 0 1

# %% [markdown]
# ## Question 6

# %%
from html.parser import HTMLParser
class HeadingParser(HTMLParser):
    
    inHeading = False
    def handle_starttag(self, tag, attrs):
        if tag == "h1" or tag == 'h2':
            self.inHeading = True
            
    def handle_data(self, data):
        if self.inHeading:
            print(data)
    def handle_endtag(self, tag):
        if tag =="h1" or tag == 'h2':
            self.inHeading = False
            print (end='    ')          # This modified code was adapted from:
                                        # https://gist.github.com/RobinDavid/9196709, on 2021-03-03.

# %%
infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#     Principles

# %% [markdown]
# ## Question 7

# %%
from urllib.parse import urljoin
from html.parser import HTMLParser
from IPython.core.display import display, HTML
from urllib.request import urlopen

class Collector(HTMLParser):
    'collects hyperlink URLs into a list'

    def __init__(self, url):
        'initializes parser, the url, and a list'
        HTMLParser.__init__(self)
        self.url = url
        self.links = []

    
    def handle_starttag(self, tag, attrs):
        'collects hyperlink URLs in their absolute format'
        if tag == 'a':
            for attr in attrs:
                if attr[0] == 'href':
                    # construct absolute URL
                    absolute = urljoin(self.url, attr[1])
                    if absolute[:4] == 'http': # collect HTTP URLs
                        self.links.append(absolute)
                        
    def getLinks(self):
        'returns hyperlinks URLs in their absolute format'
        return self.links
from urllib.request import urlopen
from urllib.parse import urljoin
from html.parser import HTMLParser

def webdir(url, depth, indent):
        
        resource = urlopen(url)
        content = resource.read().decode()
        collector = Collector(url)
        collector.feed(content)
        urls = collector.getLinks()
        
        print("{}{}".format(indent*' ', url))
        
        for URL in urls:
            #depth is greater than zero 
            if depth>0:
                webdir(URL, depth-1, indent++2)
                                                #This code was adapted from the class note of Week 6:
                                                # since the assignment link 'http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
                                                # kept giving 404 error. I used a different html link to test the code.

# %%
webdir('https://www.theanswersbay.com/', 2, 0)
# Out:
# https://www.theanswersbay.com/
#   https://www.theanswersbay.com/#content
#     https://www.theanswersbay.com/#content
#     https://www.theanswersbay.com/
#     https://www.theanswersbay.com/
#     https://www.theanswersbay.com/about-us/
#     https://www.theanswersbay.com/services/
#     https://www.theanswersbay.com/blog/
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-9fb5923ca61b> in <module>
# ----> 1 webdir('https://www.theanswersbay.com/', 2, 0)
#
# <ipython-input-2-51d053433581> in webdir(url, depth, indent)
#      44             #depth is greater than zero
#      45             if depth>0:
# ---> 46                 webdir(URL, depth-1, indent++2)
#
# <ipython-input-2-51d053433581> in webdir(url, depth, indent)
#      44             #depth is greater than zero
#      45             if depth>0:
# ...

# %% [markdown]
# ## Question 8

# %%
import sqlite3
import csv              #For this question, I had to save the assignment data as a csv file ('city.csv'),
                        #  import it to python, and insert data into a database table in 'data.db'.
con = sqlite3.connect("data.db")
cur = con.cursor()
#cur.execute ("DROP TABLE data;")

cur.execute("CREATE TABLE IF NOT EXISTS data (City, Country, Season, Temperature, Rainfall);")
a_file = open(r"C:\\Users\dtosi\Desktop\BDAT Resources\BDAT 1004 programming\city.csv")
rows = csv.reader(a_file)
cur.executemany("INSERT INTO data VALUES (?, ?, ?, ?, ?)", rows)

cur.execute("SELECT * FROM data")
print(cur.fetchall())

con.commit()
# Out:
# [('City ', 'Country ', 'Season ', 'Temperature (C) ', 'Rainfall (mm) '), ('Mumbai', 'India', 'Winter', '24.8', '5.9'), ('Mumbai', 'India', 'Spring', '28.4', '16.2'), ('Mumbai', 'India', 'Summer', '27.9', '1549.4'), ('Mumbai', 'India', 'Fall', '27.6', '346'), ('London', 'United Kingdom', 'Winter', '4.2', '207.7'), ('London', 'United Kingdom', 'Spring', '8.3', '169.6'), ('London', 'United Kingdom', 'Summer', '15.7', '157'), ('London', 'United Kingdom', 'Fall', '10.4', '218.5'), ('Cairo', 'Egypt', 'Winter', '13.6', '16.5'), ('Cairo', 'Egypt', 'Spring', '20.7', '6.5'), ('Cairo', 'Egypt', 'Summer', '27.7', '0.1'), ('Cairo', 'Egypt', 'Fall', '22.2', '4.5')]

# %%
# a) All the temparature data

cur.execute("SELECT Temperature FROM data")
for col in cur.fetchall():
    print (col[0])
# Out:
# Temperature (C)
# 24.8
# 28.4
# 27.9
# 27.6
# 4.2
# 8.3
# 15.7
# 10.4
# 13.6
# 20.7
# 27.7
# 22.2

# %%
# b) All the cities but without repitition
cur.execute("SELECT DISTINCT City FROM data")    #The DISTINCT clause in the SELECT statement
for col in cur.fetchall():                       # removes duplicate rows in the result set.
    print (col[0])
# Out:
# City
# Mumbai
# London
# Cairo

# %%
# c) All the records for india
cur.execute("SELECT * FROM data WHERE Country= 'India'")    
for row in cur.fetchall():                      
    print (row)
# Out:
# ('Mumbai', 'India', 'Winter', '24.8', '5.9')
# ('Mumbai', 'India', 'Spring', '28.4', '16.2')
# ('Mumbai', 'India', 'Summer', '27.9', '1549.4')
# ('Mumbai', 'India', 'Fall', '27.6', '346')

# %%
# d) All the fall records
cur.execute("SELECT * FROM data WHERE Season= 'Fall'")    
for row in cur.fetchall():                      
    print (row)
# Out:
# ('Mumbai', 'India', 'Fall', '27.6', '346')
# ('London', 'United Kingdom', 'Fall', '10.4', '218.5')
# ('Cairo', 'Egypt', 'Fall', '22.2', '4.5')

# %%
# e) Average rainfall is between 200 and 400 mm
cur.execute("SELECT City, Country, Season FROM data WHERE Rainfall BETWEEN '200' AND '400'")    
for row in cur.fetchall():                      
    print (row)
# Out:
# ('Mumbai', 'India', 'Fall')
# ('London', 'United Kingdom', 'Winter')
# ('London', 'United Kingdom', 'Fall')
# ('Cairo', 'Egypt', 'Fall')

# %%
# f) City and Country for average Fall temperature >20 in increasing order
cur.execute("SELECT City, Country, Temperature FROM data WHERE Temperature> '20' ORDER BY Temperature ASC;")
for row in cur.fetchall():                      
    print (row)
# Out:
# ('Cairo', 'Egypt', '20.7')
# ('Cairo', 'Egypt', '22.2')
# ('Mumbai', 'India', '24.8')
# ('Mumbai', 'India', '27.6')
# ('Cairo', 'Egypt', '27.7')
# ('Mumbai', 'India', '27.9')
# ('Mumbai', 'India', '28.4')
# ('London', 'United Kingdom', '4.2')
# ('London', 'United Kingdom', '8.3')
# ('City ', 'Country ', 'Temperature (C) ')

# %%
# g) The total annual rainfall for Cairo.
cur.execute("SELECT SUM(Rainfall) FROM data WHERE City = 'Cairo'")    
for row in cur.fetchall():                      
    print (row[0])
# Out:
# 27.6

# %%
# h) The total rainfall for each season.
cur.execute("SELECT Season, SUM(Rainfall) FROM data GROUP BY Season")    
for row in cur.fetchall():                      
    print (row)
# Out:
# ('Fall', 569.0)
# ('Season ', 0.0)
# ('Spring', 192.29999999999998)
# ('Summer', 1706.5)
# ('Winter', 230.1)

# %% [markdown]
# ## Question 9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
a = [word.upper() for word in words]
print (a)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
b = [word.lower() for word in words]
print (b)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy']

# %%
c = [len(word) for word in words]
print (c)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4]

# %%
d = [[word.upper(),  word.lower(),  len(word)] for word in words]
print (d)
# Out:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4]]

# %%
e = [word for word in words if len(word) >= 4]
print (e)
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
